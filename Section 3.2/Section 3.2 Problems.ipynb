# %% [markdown]
# ## P3.2.1
# ----

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

k_1 = 0.3
k_2 = 0.1
A_0 = 0.2
t = np.linspace(0.0, 20.0, 1000)

A = A_0 * math.e ** (-1 * (k_1 + k_2) * t)
B = (k_1 / (k_1 + k_2)) * A_0 * (1 - math.e **((-1 * k_1 + k_2) * t))
C = (k_2 / (k_1 + k_2)) * A_0 * (1 - math.e **((-1 * k_1 + k_2) * t))

plt.plot(t, A)
plt.plot(t, B)
plt.plot(t, C)

plt.show()

# %% [markdown]
# ## P3.2.2
# ----

# %%
import matplotlib.pyplot as plt
import numpy
from sympy import isprime

def isgaussprime(z: complex):
    a = int(z.real)
    b = int(z.imag)
    if a * b != 0:
        return isprime(a ** 2 + b ** 2)
    else:
        c = abs(a + b)
        return isprime(c) and c % 4 == 3

def connect(z1: complex, z2: complex):
    plt.plot([z1.real, z2.real], [z1.imag, z2.imag])
    
start = 5 + 23j
step = 1
z = start
next = None

while next != start:
    next = z + step
    connect(z, next)
    if isgaussprime(next):
        step *= 1j
    z = next

plt.axes() 

plt.show()
# Out:
# <ipython-input-36-500d8cb57a98>:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes()

# %% [markdown]
# ## P3.2.3
# ----

# %%
import matplotlib.pyplot as plt
import numpy as np

ageRange = ['<1', '1-4', '5-14', '15-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '>84']
femaleDeathRate = [1/227, 1/5376, 1/10417, 1/4132, 1/2488, 1/1106, 1/421, 1/178, 1/65, 1/21, 1/7]
maleDeathRate = [1/177, 1/4386, 1/8333, 1/1908, 1/1215, 1/663, 1/279, 1/112, 1/42, 1/15, 1/6]

plt.title('Annual risk of death for men and woment in UK')
plt.xlabel('Age Interval')
plt.ylabel('Probability of dying')

plt.plot(ageRange, np.log10(femaleDeathRate))
plt.plot(ageRange, np.log10(maleDeathRate))

plt.show()
